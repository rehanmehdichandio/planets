# %% [markdown]
# <a href="https://colab.research.google.com/github/rehanmehdichandio/planets/blob/main/Planets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the 'planets' dataset
planets = sns.load_dataset('planets')

# Display the first few rows of the dataset
print(planets.head())
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# **Basic Info and Summarry**

# %%
print(planets.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB
# None

# %%
planets.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %% [markdown]
# **Handling Missing Values**

# %%
planets.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
planets.shape
# Out:
# (1035, 6)

# %%
new_df = planets.dropna()

# %%
new_df.shape
# Out:
# (498, 6)

# %%
planets.set_index('method')
# Out:
#                  number  orbital_period   mass  distance  year
# method
# Radial Velocity       1      269.300000   7.10     77.40  2006
# Radial Velocity       1      874.774000   2.21     56.95  2008
# Radial Velocity       1      763.000000   2.60     19.84  2011
# Radial Velocity       1      326.030000  19.40    110.62  2007
# Radial Velocity       1      516.220000  10.50    119.47  2009
# ...                 ...             ...    ...       ...   ...
# Transit               1        3.941507    NaN    172.00  2006
# Transit               1        2.615864    NaN    148.00  2007
# Transit               1        3.191524    NaN    174.00  2007
# Transit               1        4.125083    NaN    293.00  2008
# Transit               1        4.187757    NaN    260.00  2008
#
# [1035 rows x 5 columns]

# %%
planets.reset_index()
# Out:
#       index           method  number  orbital_period   mass  distance  year
# 0         0  Radial Velocity       1      269.300000   7.10     77.40  2006
# 1         1  Radial Velocity       1      874.774000   2.21     56.95  2008
# 2         2  Radial Velocity       1      763.000000   2.60     19.84  2011
# 3         3  Radial Velocity       1      326.030000  19.40    110.62  2007
# 4         4  Radial Velocity       1      516.220000  10.50    119.47  2009
# ...     ...              ...     ...             ...    ...       ...   ...
# 1030   1030          Transit       1        3.941507    NaN    172.00  2006
# 1031   1031          Transit       1        2.615864    NaN    148.00  2007
# 1032   1032          Transit       1        3.191524    NaN    174.00  2007
# 1033   1033          Transit       1        4.125083    NaN    293.00  2008
# 1034   1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 7 columns]

# %%
planets.duplicated().sum()
# Out:
# 4

# %%
planets.drop_duplicates()
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1031 rows x 6 columns]

# %%
numerical_columns = planets.select_dtypes(include=['float64', 'int64']).columns
planets[numerical_columns].hist(figsize=(10, 8))
plt.show()
